# %%
import pandas as pd

# %%
df = pd.read_parquet("ETHUSDT.parquet", engine="pyarrow")

# %%
df.columns
# Out:
# Index(['open_time', 'open', 'high', 'low', 'close', 'volume',
#        'quote_asset_volume', 'num_trades', 'taker_buy_base', 'taker_buy_quote',
#        'symbol', 'log_ret_1', 'ret_5', 'ret_15', 'hl_range_pct', 'body_pct',
#        'upper_wick_pct', 'lower_wick_pct', 'sma_10_rel', 'sma_20_rel',
#        'sma_50_rel', 'ema_12_rel', 'ema_21_rel', 'ema_26_rel', 'wma_20_rel',
#        'macd_line_rel', 'macd_signal_rel', 'macd_hist_rel', 'rsi_14', 'rsi_6',
#        'stoch_k', 'stoch_d', 'stoch_cross', 'adx_14', 'di_spread',
#        'mom_10_rel', 'trix_15', 'dpo_20_rel', 'atr_rel', 'bb_pos', 'bb_width',
#        'keltner_pos', 'keltner_width', 'donchian_pos', 'ret_std_20',
#        'chaikin_vol', 'vol_stop_dist', 'volume_z', 'obv_flow', 'vwap_rel',
#        'adl_flow', 'mfi_14', 'eom_14', 'vol_osc', 'cmf_20', 'ema_cross_5_8',
#        'ema_cross_8_13', 'scalp_rsi_6', 'bb_bounce', 'macd_flip',
#        'supertrend_dir', 'bos_up', 'bos_down', 'mss_proxy', 'liq_sweep_high',
# ...
